# %% [markdown]
# <a href="https://colab.research.google.com/github/estebanurrutia1/Analitica/blob/main/Tarea_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Para la realización de la actividad es necesario que se importen las librerías con las cuales se va a realizar la manipulación de datos, calculo de métricas y graficacion de las variables que aplique

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Se carga el archivo, considerando que es de tipo csv de forma tal que quede disponible en el entorno, para realizar la manipulación y respectivo análisis

df = pd.read_csv("/content/Casos_positivos_de_COVID-19_en_Colombia..csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_14952/1326476306.py in <cell line: 0>()
#       1 # Se carga el archivo, considerando que es de tipo csv de forma tal que quede disponible en el entorno, para realizar la manipulación y respectivo análisis
#       2
# ----> 3 df = pd.read_csv("/content/Casos_positivos_de_COVID-19_en_Colombia..csv", sep=',', on_bad_lines='skip')
#
# ...

# %%
# Se revisa inicialmente el cómo está distribuido el archivo para darse una idea de qué se trata.

# Se observa las respectivas variables que lo cofoorma, en las que se observan unas que son numéricas y otras que son categóricas

# Corresponde a 23 columnas

display(df.head(5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14952/2210221798.py in <cell line: 0>()
#       5 # Corresponde a 23 columnas
#       6
# ----> 7 display(df.head(5))
#
# NameError: name 'df' is not defined

# %%
# Se observa la parte final del dataframe, indicando la cantidad de registros que la compone

display(df.tail(5))

# %%
# Se seleccionan registros aletorios, para observar si en términos generales las características del conjunto de datos

display(df.sample(5))

# %%
# Se empieza a mirar el archivo más detenida y técnicamente.

# Se observa la cantidad de registros, el nombre de la variable, el tipo de datos de cada una de cada variable, la cantidad de archivos que no son nulos, así como el rango de los índices de los datos.

# Se evdiencia incialmente tres variables que pueden ser objeto de un análisis estadístico numérico.

print(df.info())

# %%
# Se observa desde el punto de vista estadístico la tabla

# se observa que inicialmente se relacionan 3 variables son objeo de analisis estadísito y los principales estimadores se relacionan a continuación

# Para este caso se observa que es relevante realizar una posterior transformación, debido a que se tienen en notación científica, que dificulta su lectura, análisis e interpretación

display(df.describe())

# %%
# Se importa de la librería numpy, un módulo relacionado con la descripción y manejo de datos categóricos, para identificar cómo están distribuidos y partuclaridades como la cantidad de resgitros, la moda, la frecuencia, datos unbicos


from numpy import object_
display(df.describe(include=object))

# %%
# Se revisa si los datos están completos

df.isnull().sum()

# %%
# Se revisa inicialmente cómo se comporta la distribución de las variables numéricas

df["Edad"].hist()

# %%
df["Pertenencia étnica"].hist()

# %%
# Se instala lo relacionado a perfilamiento de datos accediendo a Githgub

# !pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip

# %%
# Se importan las librerías necesarias

import pandas_profiling
from pandas_profiling import ProfileReport

# %%
perfil = ProfileReport(datos, title = "Perfil de datos")
perfil

# %%
perfil.to_file(output_file="Perfil.pdf")
